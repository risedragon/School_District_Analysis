# %%
# Add the Pandas dependency.
import pandas as pd
import os

# %%
# Files to load
school_data_to_load = os.path.join("Resources","schools_complete.csv")
student_data_to_load = os.path.join("Resources","students_complete.csv")

# %%
# Read the school data file and store it in a Pandas DataFrame.
schools_df = pd.read_csv(school_data_to_load)
schools_count = schools_df.school_name.count()
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Read the student data file and store it in a Pandas DataFrame.
students_df = pd.read_csv(student_data_to_load)
students_count = students_df.student_name.count()
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
schools_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School ID    15 non-null     int64
#  1   school_name  15 non-null     object
#  2   type         15 non-null     object
#  3   size         15 non-null     int64
#  4   budget       15 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 728.0+ bytes

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39170 entries, 0 to 39169
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 2.1+ MB

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
for word in prefixes_suffixes:
    students_df["student_name"] = students_df["student_name"].str.replace(word,"")

# %%
# Check prefix and suffix
students_df[students_df['student_name'].str.contains(r'Dr. |Mr. |Ms. |Miss | MD| DDS| DVM| PhD')]
# Out:
# Empty DataFrame
# Columns: [Student ID, student_name, gender, grade, school_name, reading_score, math_score]
# Index: []

# %%
#Another way to remove prefix and suffix
students_df["student_name"] = students_df['student_name'].str.replace(r'Dr. |Mr. |Ms. |Mrs. |Miss | MD| DDS| DVM| PhD',"")

# %%
school_complete_df = students_df.merge(schools_df, on='school_name')
school_complete_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
school_complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.6+ MB

# %%
school_names = school_complete_df.school_name.unique()
school_names
# Out:
# array(['Huang High School', 'Figueroa High School', 'Shelton High School',
#        'Hernandez High School', 'Griffin High School',
#        'Wilson High School', 'Cabrera High School', 'Bailey High School',
#        'Holden High School', 'Pena High School', 'Wright High School',
#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype=object)

# %%
#Get total budget by drop duplicates
total_budget = school_complete_df.drop_duplicates(subset=['school_name'])['budget'].sum()

# %%
#Average reading score
average_reading_score = school_complete_df['reading_score'].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
# Average math score
average_math_score = school_complete_df.math_score.mean()
average_math_score
# Out:
# 78.98537145774827

# %%
# Passing Math Students
passing_math_df = school_complete_df.loc[school_complete_df.math_score >= 70,:]
passing_math_count = passing_math_df['student_name'].count()
passing_math_count
# Out:
# 29370

# %%
# Passing Reading Students
passing_reading_df = school_complete_df.loc[school_complete_df["reading_score"] >= 70,:]
passing_reading_count = passing_reading_df.student_name.count()
passing_reading_count
# Out:
# 33610

# %%
# Passing Math and Reading Students
passing_both_df = school_complete_df.query('math_score >= 70 and reading_score >= 70')
passing_both_count = passing_both_df['student_name'].count()
passing_both_count
# Out:
# 25528

# %%
# Print out Summary
print('Total students:', students_count)
passing_math_percentage = passing_math_count / students_count *100
print(f'passing math percentage: {passing_math_percentage:.2f}')
passing_reading_percentage = passing_reading_count / students_count *100
print(f'passing reading percentage: {passing_reading_percentage:.2f}')
passing_both_percentage = passing_both_count / students_count *100
print(f'passing math and reading percentage: {passing_both_percentage:.2f}')
# Out:
# Total students: 39170
# passing math percentage: 74.98
# passing reading percentage: 85.81
# passing math and reading percentage: 65.17

# %%
# Adding a list of values with keys to create a new DataFrame.
district_summary_df = pd.DataFrame(
          [{"Total Schools": schools_count,
          "Total Students": students_count,
          "Total Budget": total_budget,
          "Average Math Score": average_math_score,
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": passing_both_percentage}])
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# Format District Summary
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.2f}".format)
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)
district_summary_df.iloc[0,5:] = district_summary_df.iloc[0,5:].map("{:.0f}".format)
district_summary_df
# Out:
#    Total Schools  Total Students    Total Budget Average Math Score  \
# 0             15           39170  $24,649,428.00               79.0
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.9             75                86                65

# %%
# Reorder the columns
new_column_order = ["Total Schools", "Total Students", "Total Budget","Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]

# Assign district summary df the new column order.
district_summary_df = district_summary_df[new_column_order]
district_summary_df
# Out:
#    Total Schools  Total Students    Total Budget Average Math Score  \
# 0             15           39170  $24,649,428.00               79.0
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.9             75                86                65

# %%
# School Summary

# %%
school_summary_df = school_complete_df.groupby('school_name').agg({'type':'first','student_name':'count','budget':'first','math_score':'mean','reading_score':'mean'})

# %%
# Change Columns Title
school_summary_columns = ['School Type','Total Students','Total School Budget','Average Math Score','Average Reading Score']
school_summary_df.columns = school_summary_columns

# %%
# Adding Per Student Budget Column
school_summary_df['Per Student Budget'] = school_summary_df['Total School Budget'] / school_summary_df['Total Students']
school_summary_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
# Passing Math Students
school_passing_math = passing_math_df.groupby('school_name').agg({'student_name':'count'})['student_name']/school_summary_df['Total Students']*100
school_passing_math_df = pd.DataFrame({"% Passing Reading": school_passing_math})

# %%
# Passing Reading Students
school_passing_reading = passing_reading_df.groupby('school_name').agg({'student_name':'count'})['student_name']/school_summary_df['Total Students']*100
school_passing_reading_df = pd.DataFrame({"% Passing Math": school_passing_reading})

# %%
# Both Passing Students
school_both_passing = passing_both_df.groupby('school_name').agg({'student_name':'count'})['student_name']/school_summary_df['Total Students']*100
school_both_passing_df = pd.DataFrame({"% Overall Passing": school_both_passing})

# %%
# Merge Passing Math, Passing Reading, Both Passing
school_summary_df = school_summary_df.merge(school_passing_math_df, left_index=True, right_index=True)
school_summary_df = school_summary_df.merge(school_passing_reading_df, left_index=True, right_index=True)
school_summary_df = school_summary_df.merge(school_both_passing_df, left_index=True, right_index=True)

# %%
# Changing Columns Order
school_summary_df = school_summary_df[['School Type', 'Total Students', 'Total School Budget', 'Per Student Budget',
       'Average Math Score', 'Average Reading Score', 
       '% Passing Reading', '% Passing Math', '% Overall Passing']]
school_summary_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
# Formatting
school_summary_df['Total School Budget'] = school_summary_df['Total School Budget'].map("${:.2f}".format)
school_summary_df["Per Student Budget"] = school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# %%
school_summary_df.sort_values(["% Overall Passing"], ascending=False).head()
# Out:
#                     School Type  Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter            1858         $1081356.00
# Thomas High School      Charter            1635         $1043130.00
# Griffin High School     Charter            1468          $917500.00
# Wilson High School      Charter            2283         $1319574.00
# Pena High School        Charter             962          $585858.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Reading  % Passing Math  \
# school_name
# ...

# %%
school_summary_df.sort_values(["% Overall Passing"], ascending = True).head()
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Rodriguez High School    District            3999         $2547363.00
# Figueroa High School     District            2949         $1884411.00
# Huang High School        District            2917         $1910635.00
# Hernandez High School    District            4635         $3022020.00
# Johnson High School      District            4761         $3094650.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Reading  \
# school_name
# Rodriguez High School              80.744686          66.366592
# ...

# %%
# Math score by school and grade
school_complete_df["grade"] = pd.Categorical(school_complete_df["grade"],["9th","10th","11th","12th"])
school_complete_df[["school_name","grade","math_score"]].groupby(["school_name", "grade"]).mean().unstack("grade").applymap("{:.1f}".format)
# Out:
#                       math_score
# grade                        9th  10th  11th  12th
# school_name
# Bailey High School          77.1  77.0  77.5  76.5
# Cabrera High School         83.1  83.2  82.8  83.3
# Figueroa High School        76.4  76.5  76.9  77.2
# Ford High School            77.4  77.7  76.9  76.2
# Griffin High School         82.0  84.2  83.8  83.4
# Hernandez High School       77.4  77.3  77.1  77.2
# Holden High School          83.8  83.4  85.0  82.9
# Huang High School           77.0  75.9  76.4  77.2
# Johnson High School         77.2  76.7  77.5  76.9
# Pena High School            83.6  83.4  84.3  84.1
# Rodriguez High School       76.9  76.6  76.4  77.7
# Shelton High School         83.4  82.9  83.4  83.8
# Thomas High School          83.6  83.1  83.5  83.5
# Wilson High School          83.1  83.7  83.2  83.0
# Wright High School          83.3  84.0  83.8  83.6

# %%
# Reading score by school and grade
school_complete_df[["school_name","grade","reading_score"]].groupby(["school_name", "grade"]).mean().unstack("grade").applymap("{:.1f}".format)
# Out:
#                       reading_score
# grade                           9th  10th  11th  12th
# school_name
# Bailey High School             81.3  80.9  80.9  80.9
# Cabrera High School            83.7  84.3  83.8  84.3
# Figueroa High School           81.2  81.4  80.6  81.4
# Ford High School               80.6  81.3  80.4  80.7
# Griffin High School            83.4  83.7  84.3  84.0
# Hernandez High School          80.9  80.7  81.4  80.9
# Holden High School             83.7  83.3  83.8  84.7
# Huang High School              81.3  81.5  81.4  80.3
# Johnson High School            81.3  80.8  80.6  81.2
# Pena High School               83.8  83.6  84.3  84.6
# Rodriguez High School          81.0  80.6  80.9  80.4
# Shelton High School            84.1  83.4  84.4  82.8
# Thomas High School             83.7  84.3  83.6  83.8
# Wilson High School             83.9  84.0  83.8  84.3
# Wright High School             83.8  83.8  84.2  84.1

# %% [markdown]
# # Establish the Spending Ranges per Student

# %%
# Establish the spending bins and group names.
spending_bins = [0, 585, 630, 645, 675]
group_names = ["<$584", "$585-629", "$630-644", "$645-675"]
# Categorize spending based on the bins.
school_summary_df["Spending Ranges (Per Student)"]= pd.cut(school_summary_df['Per Student Budget'].replace('[\$]','',regex=True).astype('float'),spending_bins,labels = group_names)

# %%
school_summary_df.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# school_name
# Bailey High School      District            4976         $3124928.00
# Cabrera High School      Charter            1858         $1081356.00
# Figueroa High School    District            2949         $1884411.00
# Ford High School        District            2739         $1763916.00
# Griffin High School      Charter            1468          $917500.00
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Reading  \
# school_name
# Bailey High School                81.033963          66.680064
# ...

# %%
spending_summary_df = school_summary_df.groupby('Spending Ranges (Per Student)').mean()[['Average Math Score', 'Average Reading Score',
       '% Passing Reading', '% Passing Math', '% Overall Passing']]

# %%
spending_summary_df[['Average Math Score', 'Average Reading Score']] = spending_summary_df[['Average Math Score', 'Average Reading Score']].applymap('{:.1f}'.format)
spending_summary_df[['% Passing Reading', '% Passing Math', '% Overall Passing']] = spending_summary_df[['% Passing Reading', '% Passing Math', '% Overall Passing']].applymap('{:.0f}'.format)

# %%
spending_summary_df
# Out:
#                               Average Math Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                       83.5                  83.9
# $585-629                                    81.9                  83.2
# $630-644                                    78.5                  81.6
# $645-675                                    77.0                  81.0
#
#                               % Passing Reading % Passing Math  \
# Spending Ranges (Per Student)
# <$584                                        93             97
# $585-629                                     87             93
# $630-644                                     73             84
# $645-675                                     66             81
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$584                                        90
# $585-629                                     81
# $630-644                                     63
# ...

# %% [markdown]
# # Create Bins for School

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Categorize spending based on the bins
school_summary_df["School Size"] = pd.cut(school_summary_df['Total Students'], size_bins, labels = group_names)

# %%
school_summary_df.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# school_name
# Bailey High School      District            4976         $3124928.00
# Cabrera High School      Charter            1858         $1081356.00
# Figueroa High School    District            2949         $1884411.00
# Ford High School        District            2739         $1763916.00
# Griffin High School      Charter            1468          $917500.00
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Reading  \
# school_name
# Bailey High School                81.033963          66.680064
# ...

# %%
size_summary_df = school_summary_df.groupby(['School Size']).mean()[['Average Math Score', 'Average Reading Score',
       '% Passing Reading', '% Passing Math', '% Overall Passing']]

# %%
# Formatting.
size_summary_df[['Average Math Score', 'Average Reading Score']] = size_summary_df[['Average Math Score', 'Average Reading Score']].applymap('{:.1f}'.format)
size_summary_df[['% Passing Reading', '% Passing Math', '% Overall Passing']] = size_summary_df[['% Passing Reading', '% Passing Math', '% Overall Passing']].applymap('{:.0f}'.format)

# %%
size_summary_df
# Out:
#                    Average Math Score Average Reading Score % Passing Reading  \
# School Size
# Small (<1000)                    83.8                  83.9                94
# Medium (1000-2000)               83.4                  83.9                94
# Large (2000-5000)                77.7                  81.3                70
#
#                    % Passing Math % Overall Passing
# School Size
# Small (<1000)                  96                90
# Medium (1000-2000)             97                91
# Large (2000-5000)              83                58
